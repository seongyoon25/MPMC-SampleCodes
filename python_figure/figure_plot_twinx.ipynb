# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,3))
color = sns.color_palette('inferno', 3)

plt.plot(...)
plt.xscale('log')
plt.xlabel(r'$\tau$ (s)')
plt.ylabel(fr'DRT $\gamma \, (\ln{{\tau}})$ $(\Omega)$')
plt.tick_params(axis='y', labelcolor='r')
plt.ylim([0, 1.2])
plt.yticks(np.linspace(0, 1.2, 5), fontsize=12)

plt.plot([], [], 'k', linewidth=2, label='HMC DRT')
plt.plot([], [], '-', color=color[0], label='SOH 100%')
plt.plot([], [], '-', color=color[1], label='SOH 80%')
plt.plot([], [], '-', color=color[2], label='SOH 60%')

plt.legend(loc=(.02,.55), fontsize=12, frameon=False)
plt.grid()

plt.twinx()
color = sns.color_palette('winter', 3)

plt.plot(...)
plt.ylabel(fr'DDT $\gamma \, (\ln{{\tau}})$ $(\Omega)$', rotation=-90)
plt.tick_params(axis='y', labelcolor='b')
plt.ylim([0, 14])
plt.yticks(np.linspace(0, 14, 5), fontsize=12)

plt.plot([], [], 'k--', linewidth=2, label='HMC DDT')
plt.plot([], [], '--', color=color[0], label='SOH 100%')
plt.plot([], [], '--', color=color[1], label='SOH 80%')
plt.plot([], [], '--', color=color[2], label='SOH 60%')

plt.legend(loc=(.02,.1), fontsize=12, frameon=False)
plt.show()
