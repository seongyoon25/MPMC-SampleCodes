# %% [markdown]
# # 0. Import modules and setting path, cuda

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Make dataframe to plot boxplot
MAE_total = pd.DataFrame()
sigmas = [0.001, 0.003, 0.01]
for window_size in [1, 3, 10, 50]:
    MAE = pd.DataFrame(...)
    MAE['window_size'] = window_size
    MAE_total = MAE_total.append(MAE, ignore_index=True)
MAE_total = pd.melt(MAE_total, 'window_size', var_name='sigma')

plt.rc('axes', linewidth=2)

plt.figure(figsize=(8,5))
ax = sns.boxplot(x='window_size', y='value', hue='sigma', data=MAE_total, palette='gnuplot2', linewidth=2)
plt.xlabel('Input cycle number', fontsize=24)
plt.xticks(fontsize=20)
plt.ylabel('MAE deviation (Ah)', fontsize=24)
plt.yticks(fontsize=20)
ax.yaxis.get_offset_text().set_fontsize(18)

plt.grid()

plt.ticklabel_format(axis='y', scilimits=(0,0))
ticks = ax.get_yticks()
dticks = ticks[1] - ticks[0]
plt.ylim([ticks[1] - dticks/2, ticks[-2] + dticks/2])

# Change legend manually
L = plt.legend(fontsize=20)
for i, sigma in enumerate(sigmas):
    L.get_texts()[i].set_text(f'$\sigma={sigma}$')

figure_name = ...
plt.savefig(f'{figure_name}.eps', bbox_inches='tight', dpi=300)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
