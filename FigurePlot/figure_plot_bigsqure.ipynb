# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
crates = ['C/2', '1C', '2C', '4C', '6C', '8C']

# %%
plt.rc('axes', linewidth=2)

color = sns.color_palette('gnuplot2_r', len(crates)+1)[1:]

plt.figure(figsize=(8,6))
for i, crate in enumerate(crates):
    
    # References
    plt.plot(..., 'k.', zorder=100, linewidth=2)
    
    # Estimation
    plt.plot(..., color=color[i], linewidth=2)
    plt.plot([], [], color=color[i], linewidth=3, label=crate)
    
    # 95% CI
    x_lower = ...
    y_lower = ...
    x_upper = ...
    y_upper = ...
    plt.fill(np.concatenate([x_lower, x_upper[::-1]]), 
             np.concatenate([y_lower, y_upper[::-1]]),
             facecolor='paleturquoise', edgecolor='paleturquoise')

# Additional legend
plt.fill([], [], facecolor='paleturquoise', edgecolor='paleturquoise', label='95% CI')
plt.plot([], [], 'ko', label='References', linewidth=3)
plt.legend(fontsize=16.5, bbox_to_anchor=(0.2, -0.04), loc='lower left', frameon=False)

# Configure
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)
plt.xlabel('Capacity (Ahm$^{-2}$)', fontsize=24)
plt.ylabel('Voltage (V)', fontsize=24)
plt.yticks(np.arange(2.4, 4.4, 0.2))
plt.ylim([2.5, 4.2])
plt.xlim([0, 31])

# Save and Show
figure_name = ...
plt.savefig(f'{figure_name}.eps', bbox_inches='tight', dpi=300)
plt.show()
